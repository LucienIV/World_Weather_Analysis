# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 742

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | east london
# Processing Record 2 of Set 1 | severo-kurilsk
# Processing Record 3 of Set 1 | warmbad
# Processing Record 4 of Set 1 | mogadishu
# Processing Record 5 of Set 1 | chokurdakh
# Processing Record 6 of Set 1 | yellowknife
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | cherskiy
# Processing Record 12 of Set 1 | eldorado
# Processing Record 13 of Set 1 | mar del plata
# Processing Record 14 of Set 1 | ilulissat
# Processing Record 15 of Set 1 | george town
# Processing Record 16 of Set 1 | prince rupert
# Processing Record 17 of Set 1 | hilo
# Processing Record 18 of Set 1 | jurado
# Processing Record 19 of Set 1 | uch
# Processing Record 20 of Set 1 | albania
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | jiddah
# City not found. Skipping...
# Processing Record 23 of Set 1 | ribeira grande
# Processing Record 24 of Set 1 | beringovskiy
# Processing Record 25 of Set 1 | castro
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | abashiri
# Processing Record 28 of Set 1 | buluang
# Processing Record 29 of Set 1 | pangnirtung
# Processing Record 30 of Set 1 | shelburne
# Processing Record 31 of Set 1 | bukachacha
# Processing Record 32 of Set 1 | port lincoln
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | hambantota
# Processing Record 35 of Set 1 | nishihara
# Processing Record 36 of Set 1 | port macquarie
# Processing Record 37 of Set 1 | almaznyy
# Processing Record 38 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 1 | la primavera
# Processing Record 40 of Set 1 | kapaa
# Processing Record 41 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 1 | cap malheureux
# Processing Record 43 of Set 1 | punta arenas
# Processing Record 44 of Set 1 | zambezi
# Processing Record 45 of Set 1 | rikitea
# Processing Record 46 of Set 1 | kilindoni
# Processing Record 47 of Set 1 | talnakh
# Processing Record 48 of Set 1 | nuoro
# Processing Record 49 of Set 1 | luwuk
# Processing Record 50 of Set 1 | tazovskiy
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | lompoc
# Processing Record 3 of Set 2 | dikson
# Processing Record 4 of Set 2 | kutum
# Processing Record 5 of Set 2 | cockburn town
# Processing Record 6 of Set 2 | yenotayevka
# Processing Record 7 of Set 2 | tara
# Processing Record 8 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 9 of Set 2 | zyryanka
# Processing Record 10 of Set 2 | khatanga
# Processing Record 11 of Set 2 | thompson
# Processing Record 12 of Set 2 | ponta do sol
# Processing Record 13 of Set 2 | avarua
# Processing Record 14 of Set 2 | fukue
# Processing Record 15 of Set 2 | rosarito
# Processing Record 16 of Set 2 | fortuna
# Processing Record 17 of Set 2 | vaini
# Processing Record 18 of Set 2 | arraial do cabo
# Processing Record 19 of Set 2 | keffi
# Processing Record 20 of Set 2 | margate
# Processing Record 21 of Set 2 | baykit
# Processing Record 22 of Set 2 | quatre cocos
# Processing Record 23 of Set 2 | puerto ayora
# Processing Record 24 of Set 2 | the pas
# Processing Record 25 of Set 2 | butaritari
# Processing Record 26 of Set 2 | priyutnoye
# Processing Record 27 of Set 2 | maumere
# Processing Record 28 of Set 2 | thinadhoo
# Processing Record 29 of Set 2 | lavrentiya
# Processing Record 30 of Set 2 | gasa
# Processing Record 31 of Set 2 | barrow
# Processing Record 32 of Set 2 | narsaq
# Processing Record 33 of Set 2 | bol
# Processing Record 34 of Set 2 | port alfred
# Processing Record 35 of Set 2 | mount darwin
# Processing Record 36 of Set 2 | hermanus
# Processing Record 37 of Set 2 | luderitz
# Processing Record 38 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 2 | bredasdorp
# Processing Record 40 of Set 2 | kamiiso
# Processing Record 41 of Set 2 | mumford
# Processing Record 42 of Set 2 | cape town
# Processing Record 43 of Set 2 | yatou
# Processing Record 44 of Set 2 | tasiilaq
# Processing Record 45 of Set 2 | tuktoyaktuk
# Processing Record 46 of Set 2 | saint-pierre
# Processing Record 47 of Set 2 | tabou
# Processing Record 48 of Set 2 | binga
# Processing Record 49 of Set 2 | aklavik
# Processing Record 50 of Set 2 | faanui
# Processing Record 1 of Set 3 | vardo
# Processing Record 2 of Set 3 | inirida
# Processing Record 3 of Set 3 | viedma
# Processing Record 4 of Set 3 | upernavik
# Processing Record 5 of Set 3 | nelson bay
# Processing Record 6 of Set 3 | clyde river
# Processing Record 7 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 3 | leningradskiy
# Processing Record 9 of Set 3 | loksa
# Processing Record 10 of Set 3 | new norfolk
# Processing Record 11 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 3 | lebu
# Processing Record 13 of Set 3 | tulun
# Processing Record 14 of Set 3 | geraldton
# Processing Record 15 of Set 3 | nara
# Processing Record 16 of Set 3 | rantepao
# Processing Record 17 of Set 3 | victoria
# Processing Record 18 of Set 3 | jharsuguda
# Processing Record 19 of Set 3 | vostok
# Processing Record 20 of Set 3 | tiarei
# Processing Record 21 of Set 3 | korgen
# Processing Record 22 of Set 3 | kaitangata
# Processing Record 23 of Set 3 | ikalamavony
# Processing Record 24 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 25 of Set 3 | krasnooktyabrskiy
# Processing Record 26 of Set 3 | carnarvon
# Processing Record 27 of Set 3 | beniganj
# Processing Record 28 of Set 3 | ketchikan
# Processing Record 29 of Set 3 | puerto escondido
# Processing Record 30 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 3 | bathsheba
# Processing Record 33 of Set 3 | fairbanks
# Processing Record 34 of Set 3 | mahebourg
# Processing Record 35 of Set 3 | lingyuan
# Processing Record 36 of Set 3 | champerico
# Processing Record 37 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 3 | jiuquan
# Processing Record 40 of Set 3 | cam ranh
# Processing Record 41 of Set 3 | kodiak
# Processing Record 42 of Set 3 | saskylakh
# Processing Record 43 of Set 3 | touros
# Processing Record 44 of Set 3 | turayf
# Processing Record 45 of Set 3 | nyurba
# Processing Record 46 of Set 3 | sistranda
# Processing Record 47 of Set 3 | baruun-urt
# Processing Record 48 of Set 3 | tashara
# Processing Record 49 of Set 3 | muros
# Processing Record 50 of Set 3 | nuuk
# Processing Record 1 of Set 4 | maragogi
# Processing Record 2 of Set 4 | najran
# Processing Record 3 of Set 4 | atuona
# Processing Record 4 of Set 4 | tawkar
# City not found. Skipping...
# Processing Record 5 of Set 4 | shingu
# Processing Record 6 of Set 4 | alugan
# Processing Record 7 of Set 4 | mao
# Processing Record 8 of Set 4 | labuhan
# Processing Record 9 of Set 4 | xixiang
# Processing Record 10 of Set 4 | nikolskoye
# Processing Record 11 of Set 4 | yaan
# Processing Record 12 of Set 4 | samarai
# Processing Record 13 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 4 | mersing
# Processing Record 15 of Set 4 | ratnagiri
# Processing Record 16 of Set 4 | chuy
# Processing Record 17 of Set 4 | codrington
# Processing Record 18 of Set 4 | lorengau
# Processing Record 19 of Set 4 | caluquembe
# Processing Record 20 of Set 4 | korla
# Processing Record 21 of Set 4 | ahipara
# Processing Record 22 of Set 4 | terney
# Processing Record 23 of Set 4 | norman wells
# Processing Record 24 of Set 4 | grindavik
# Processing Record 25 of Set 4 | sinnamary
# Processing Record 26 of Set 4 | anadyr
# Processing Record 27 of Set 4 | olafsvik
# Processing Record 28 of Set 4 | namibe
# Processing Record 29 of Set 4 | khorixas
# Processing Record 30 of Set 4 | voh
# Processing Record 31 of Set 4 | tarakan
# Processing Record 32 of Set 4 | ponazyrevo
# Processing Record 33 of Set 4 | bandarbeyla
# Processing Record 34 of Set 4 | gelibolu
# Processing Record 35 of Set 4 | pitimbu
# Processing Record 36 of Set 4 | aksu
# Processing Record 37 of Set 4 | beruwala
# Processing Record 38 of Set 4 | rio gallegos
# Processing Record 39 of Set 4 | eureka
# Processing Record 40 of Set 4 | arlit
# Processing Record 41 of Set 4 | humaita
# Processing Record 42 of Set 4 | tiradentes
# Processing Record 43 of Set 4 | hami
# Processing Record 44 of Set 4 | bambanglipuro
# Processing Record 45 of Set 4 | pevek
# Processing Record 46 of Set 4 | auki
# Processing Record 47 of Set 4 | bubaque
# Processing Record 48 of Set 4 | porto belo
# Processing Record 49 of Set 4 | normandin
# Processing Record 50 of Set 4 | brainerd
# Processing Record 1 of Set 5 | monticello
# Processing Record 2 of Set 5 | cabo san lucas
# Processing Record 3 of Set 5 | taltal
# Processing Record 4 of Set 5 | saint-philippe
# Processing Record 5 of Set 5 | ancud
# Processing Record 6 of Set 5 | taoudenni
# Processing Record 7 of Set 5 | caravelas
# Processing Record 8 of Set 5 | camacha
# Processing Record 9 of Set 5 | alegrete
# Processing Record 10 of Set 5 | sitka
# Processing Record 11 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 12 of Set 5 | qaanaaq
# Processing Record 13 of Set 5 | vao
# Processing Record 14 of Set 5 | port pirie
# Processing Record 15 of Set 5 | lagoa
# Processing Record 16 of Set 5 | raudeberg
# Processing Record 17 of Set 5 | hualmay
# Processing Record 18 of Set 5 | knyaginino
# Processing Record 19 of Set 5 | parabel
# Processing Record 20 of Set 5 | el tocuyo
# Processing Record 21 of Set 5 | guerrero negro
# Processing Record 22 of Set 5 | mahina
# Processing Record 23 of Set 5 | sorland
# Processing Record 24 of Set 5 | tadine
# Processing Record 25 of Set 5 | adrar
# Processing Record 26 of Set 5 | lisakovsk
# Processing Record 27 of Set 5 | coolum beach
# Processing Record 28 of Set 5 | kavieng
# Processing Record 29 of Set 5 | olinda
# Processing Record 30 of Set 5 | palmer
# Processing Record 31 of Set 5 | inhambane
# Processing Record 32 of Set 5 | oskarshamn
# Processing Record 33 of Set 5 | laguna
# Processing Record 34 of Set 5 | koumac
# Processing Record 35 of Set 5 | skjervoy
# Processing Record 36 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 5 | half moon bay
# Processing Record 38 of Set 5 | inverness
# Processing Record 39 of Set 5 | misratah
# Processing Record 40 of Set 5 | miyako
# Processing Record 41 of Set 5 | hasaki
# Processing Record 42 of Set 5 | benguela
# Processing Record 43 of Set 5 | sarkand
# Processing Record 44 of Set 5 | sunrise manor
# Processing Record 45 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 5 | mayskiy
# Processing Record 47 of Set 5 | haines junction
# Processing Record 48 of Set 5 | esperance
# Processing Record 49 of Set 5 | matara
# Processing Record 50 of Set 5 | marseille
# Processing Record 1 of Set 6 | longyearbyen
# Processing Record 2 of Set 6 | moreira sales
# Processing Record 3 of Set 6 | nyrob
# Processing Record 4 of Set 6 | saldanha
# Processing Record 5 of Set 6 | morant bay
# Processing Record 6 of Set 6 | salalah
# Processing Record 7 of Set 6 | guajara-mirim
# City not found. Skipping...
# Processing Record 8 of Set 6 | pemangkat
# Processing Record 9 of Set 6 | lincoln
# Processing Record 10 of Set 6 | rawah
# Processing Record 11 of Set 6 | lata
# Processing Record 12 of Set 6 | puerto leguizamo
# Processing Record 13 of Set 6 | airai
# Processing Record 14 of Set 6 | halifax
# Processing Record 15 of Set 6 | tuatapere
# Processing Record 16 of Set 6 | flin flon
# Processing Record 17 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 6 | aykhal
# Processing Record 19 of Set 6 | pundaguitan
# Processing Record 20 of Set 6 | bambous virieux
# Processing Record 21 of Set 6 | hithadhoo
# Processing Record 22 of Set 6 | chadan
# Processing Record 23 of Set 6 | sao felix do xingu
# Processing Record 24 of Set 6 | wuda
# Processing Record 25 of Set 6 | kudahuvadhoo
# Processing Record 26 of Set 6 | oktyabrskoye
# Processing Record 27 of Set 6 | katsuura
# Processing Record 28 of Set 6 | mount pleasant
# Processing Record 29 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 6 | penzance
# Processing Record 31 of Set 6 | shache
# Processing Record 32 of Set 6 | yar-sale
# Processing Record 33 of Set 6 | praxedis guerrero
# Processing Record 34 of Set 6 | princeton
# Processing Record 35 of Set 6 | menongue
# Processing Record 36 of Set 6 | cabra
# Processing Record 37 of Set 6 | fairmont
# Processing Record 38 of Set 6 | ambilobe
# Processing Record 39 of Set 6 | pemba
# Processing Record 40 of Set 6 | siocon
# Processing Record 41 of Set 6 | dong hoi
# Processing Record 42 of Set 6 | talara
# Processing Record 43 of Set 6 | ribeira brava
# Processing Record 44 of Set 6 | prainha
# Processing Record 45 of Set 6 | mozarlandia
# Processing Record 46 of Set 6 | vangaindrano
# Processing Record 47 of Set 6 | komsomolskiy
# Processing Record 48 of Set 6 | tautira
# Processing Record 49 of Set 6 | los lunas
# Processing Record 50 of Set 6 | hovd
# Processing Record 1 of Set 7 | porto torres
# Processing Record 2 of Set 7 | ternate
# Processing Record 3 of Set 7 | kahului
# Processing Record 4 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 5 of Set 7 | ruteng
# Processing Record 6 of Set 7 | richards bay
# Processing Record 7 of Set 7 | coahuayana
# Processing Record 8 of Set 7 | san policarpo
# Processing Record 9 of Set 7 | malvern
# Processing Record 10 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 7 | alice springs
# Processing Record 12 of Set 7 | tiksi
# Processing Record 13 of Set 7 | salinas
# Processing Record 14 of Set 7 | euclides da cunha
# Processing Record 15 of Set 7 | souillac
# Processing Record 16 of Set 7 | smithers
# Processing Record 17 of Set 7 | henties bay
# Processing Record 18 of Set 7 | kieta
# Processing Record 19 of Set 7 | bousso
# Processing Record 20 of Set 7 | balikpapan
# Processing Record 21 of Set 7 | gat
# Processing Record 22 of Set 7 | raga
# Processing Record 23 of Set 7 | keti bandar
# Processing Record 24 of Set 7 | bengkulu
# Processing Record 25 of Set 7 | iqaluit
# Processing Record 26 of Set 7 | nokaneng
# Processing Record 27 of Set 7 | provideniya
# Processing Record 28 of Set 7 | bajo baudo
# City not found. Skipping...
# Processing Record 29 of Set 7 | ankang
# Processing Record 30 of Set 7 | georgetown
# Processing Record 31 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 7 | sola
# Processing Record 33 of Set 7 | kamenka
# Processing Record 34 of Set 7 | san patricio
# Processing Record 35 of Set 7 | ulaanbaatar
# Processing Record 36 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 7 | porto novo
# Processing Record 38 of Set 7 | vagur
# Processing Record 39 of Set 7 | ewa beach
# Processing Record 40 of Set 7 | mirandopolis
# Processing Record 41 of Set 7 | muli
# Processing Record 42 of Set 7 | taunggyi
# Processing Record 43 of Set 7 | ugoofaaru
# Processing Record 44 of Set 7 | pangkalanbuun
# Processing Record 45 of Set 7 | tsentralnyy
# City not found. Skipping...
# Processing Record 46 of Set 7 | dalvik
# Processing Record 47 of Set 7 | ulladulla
# Processing Record 48 of Set 7 | lardos
# Processing Record 49 of Set 7 | isetskoye
# Processing Record 50 of Set 7 | krasnoselkup
# Processing Record 1 of Set 8 | sarai
# Processing Record 2 of Set 8 | emba
# Processing Record 3 of Set 8 | ishigaki
# Processing Record 4 of Set 8 | cidreira
# Processing Record 5 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 8 | nanortalik
# Processing Record 7 of Set 8 | sirajganj
# Processing Record 8 of Set 8 | arman
# Processing Record 9 of Set 8 | nome
# Processing Record 10 of Set 8 | kavaratti
# Processing Record 11 of Set 8 | aleksandrov gay
# Processing Record 12 of Set 8 | pacaembu
# Processing Record 13 of Set 8 | san quintin
# Processing Record 14 of Set 8 | labuan
# Processing Record 15 of Set 8 | seoul
# Processing Record 16 of Set 8 | nhulunbuy
# Processing Record 17 of Set 8 | lexington
# Processing Record 18 of Set 8 | jacareacanga
# Processing Record 19 of Set 8 | zachagansk
# City not found. Skipping...
# Processing Record 20 of Set 8 | maceio
# Processing Record 21 of Set 8 | acapulco
# Processing Record 22 of Set 8 | solsvik
# City not found. Skipping...
# Processing Record 23 of Set 8 | ksenyevka
# City not found. Skipping...
# Processing Record 24 of Set 8 | luganville
# Processing Record 25 of Set 8 | ankazoabo
# Processing Record 26 of Set 8 | meulaboh
# Processing Record 27 of Set 8 | bethel
# Processing Record 28 of Set 8 | baghdad
# Processing Record 29 of Set 8 | punta de bombon
# Processing Record 30 of Set 8 | calebasses
# Processing Record 31 of Set 8 | westport
# Processing Record 32 of Set 8 | avera
# Processing Record 33 of Set 8 | wattegama
# Processing Record 34 of Set 8 | bonito
# Processing Record 35 of Set 8 | turukhansk
# Processing Record 36 of Set 8 | caernarfon
# Processing Record 37 of Set 8 | castrillon
# Processing Record 38 of Set 8 | muravlenko
# Processing Record 39 of Set 8 | batsfjord
# Processing Record 40 of Set 8 | spencer
# Processing Record 41 of Set 8 | itarema
# Processing Record 42 of Set 8 | santa cruz de rosales
# City not found. Skipping...
# Processing Record 43 of Set 8 | deputatskiy
# Processing Record 44 of Set 8 | isla vista
# Processing Record 45 of Set 8 | zalantun
# Processing Record 46 of Set 8 | maun
# Processing Record 47 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 48 of Set 8 | roma
# Processing Record 49 of Set 8 | solnechnyy
# Processing Record 50 of Set 8 | dunedin
# Processing Record 1 of Set 9 | chumikan
# Processing Record 2 of Set 9 | las conchas
# Processing Record 3 of Set 9 | isangel
# Processing Record 4 of Set 9 | san carlos park
# Processing Record 5 of Set 9 | nuzvid
# Processing Record 6 of Set 9 | lipin bor
# Processing Record 7 of Set 9 | mehamn
# Processing Record 8 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 9 | bima
# Processing Record 11 of Set 9 | goroka
# Processing Record 12 of Set 9 | kuhestan
# City not found. Skipping...
# Processing Record 13 of Set 9 | tonantins
# Processing Record 14 of Set 9 | inta
# Processing Record 15 of Set 9 | yemtsa
# Processing Record 16 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 9 | altay
# Processing Record 18 of Set 9 | maghama
# City not found. Skipping...
# Processing Record 19 of Set 9 | chapais
# Processing Record 20 of Set 9 | dekoa
# City not found. Skipping...
# Processing Record 21 of Set 9 | marrakesh
# Processing Record 22 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 9 | ostrovnoy
# Processing Record 24 of Set 9 | ormara
# Processing Record 25 of Set 9 | dudinka
# Processing Record 26 of Set 9 | darlowo
# Processing Record 27 of Set 9 | khasan
# Processing Record 28 of Set 9 | emborion
# Processing Record 29 of Set 9 | rocha
# Processing Record 30 of Set 9 | lumby
# Processing Record 31 of Set 9 | yurla
# Processing Record 32 of Set 9 | fereydun kenar
# Processing Record 33 of Set 9 | kemijarvi
# Processing Record 34 of Set 9 | padang
# Processing Record 35 of Set 9 | karratha
# Processing Record 36 of Set 9 | gombe
# Processing Record 37 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 38 of Set 9 | vila
# Processing Record 39 of Set 9 | tevriz
# Processing Record 40 of Set 9 | salta
# Processing Record 41 of Set 9 | sehithwa
# Processing Record 42 of Set 9 | marzuq
# Processing Record 43 of Set 9 | bundaberg
# Processing Record 44 of Set 9 | werder
# Processing Record 45 of Set 9 | aguas verdes
# Processing Record 46 of Set 9 | phalombe
# Processing Record 47 of Set 9 | moerai
# Processing Record 48 of Set 9 | leh
# Processing Record 49 of Set 9 | camapua
# Processing Record 50 of Set 9 | marystown
# Processing Record 1 of Set 10 | medea
# Processing Record 2 of Set 10 | port elizabeth
# Processing Record 3 of Set 10 | nantucket
# Processing Record 4 of Set 10 | kamloops
# Processing Record 5 of Set 10 | sabaudia
# Processing Record 6 of Set 10 | markova
# Processing Record 7 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 8 of Set 10 | kamogawa
# Processing Record 9 of Set 10 | saint-joseph
# Processing Record 10 of Set 10 | gimli
# Processing Record 11 of Set 10 | estelle
# Processing Record 12 of Set 10 | faratsiho
# Processing Record 13 of Set 10 | saint george
# Processing Record 14 of Set 10 | chuguyevka
# Processing Record 15 of Set 10 | terenos
# Processing Record 16 of Set 10 | hun
# Processing Record 17 of Set 10 | bilma
# Processing Record 18 of Set 10 | muyuka
# Processing Record 19 of Set 10 | bitung
# Processing Record 20 of Set 10 | dicabisagan
# Processing Record 21 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 10 | sept-iles
# Processing Record 23 of Set 10 | xiaoweizhai
# Processing Record 24 of Set 10 | roebourne
# Processing Record 25 of Set 10 | viru
# Processing Record 26 of Set 10 | berlevag
# Processing Record 27 of Set 10 | kumla
# Processing Record 28 of Set 10 | ponta delgada
# Processing Record 29 of Set 10 | lephepe
# City not found. Skipping...
# Processing Record 30 of Set 10 | methoni
# Processing Record 31 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 32 of Set 10 | stephenville
# Processing Record 33 of Set 10 | iowa city
# Processing Record 34 of Set 10 | lokosovo
# Processing Record 35 of Set 10 | kaeo
# Processing Record 36 of Set 10 | wanaka
# Processing Record 37 of Set 10 | la esperanza
# Processing Record 38 of Set 10 | ust-uda
# Processing Record 39 of Set 10 | changde
# Processing Record 40 of Set 10 | broken hill
# Processing Record 41 of Set 10 | northampton
# Processing Record 42 of Set 10 | stellenbosch
# Processing Record 43 of Set 10 | bahia blanca
# Processing Record 44 of Set 10 | swan river
# Processing Record 45 of Set 10 | rafsanjan
# Processing Record 46 of Set 10 | mongoumba
# Processing Record 47 of Set 10 | derzhavinsk
# Processing Record 48 of Set 10 | maravilha
# Processing Record 49 of Set 10 | portland
# Processing Record 50 of Set 10 | nanakuli
# Processing Record 1 of Set 11 | tual
# Processing Record 2 of Set 11 | torbay
# Processing Record 3 of Set 11 | husavik
# Processing Record 4 of Set 11 | tashla
# Processing Record 5 of Set 11 | chara
# Processing Record 6 of Set 11 | outjo
# Processing Record 7 of Set 11 | verkhnetulomskiy
# Processing Record 8 of Set 11 | mount isa
# Processing Record 9 of Set 11 | boguchany
# Processing Record 10 of Set 11 | nador
# Processing Record 11 of Set 11 | sao joao da barra
# Processing Record 12 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 13 of Set 11 | kayerkan
# Processing Record 14 of Set 11 | burila mare
# Processing Record 15 of Set 11 | santa maria da vitoria
# Processing Record 16 of Set 11 | belyy yar
# Processing Record 17 of Set 11 | puri
# Processing Record 18 of Set 11 | emerald
# Processing Record 19 of Set 11 | boa vista
# Processing Record 20 of Set 11 | moron
# Processing Record 21 of Set 11 | tezu
# Processing Record 22 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 23 of Set 11 | poum
# Processing Record 24 of Set 11 | fort nelson
# Processing Record 25 of Set 11 | chicama
# Processing Record 26 of Set 11 | lasa
# Processing Record 27 of Set 11 | valdivia
# Processing Record 28 of Set 11 | sur
# Processing Record 29 of Set 11 | pisco
# Processing Record 30 of Set 11 | jian
# Processing Record 31 of Set 11 | oranmore
# Processing Record 32 of Set 11 | leshukonskoye
# Processing Record 33 of Set 11 | kampong chhnang
# Processing Record 34 of Set 11 | udachnyy
# Processing Record 35 of Set 11 | bemidji
# Processing Record 36 of Set 11 | high level
# Processing Record 37 of Set 11 | erenhot
# Processing Record 38 of Set 11 | la plata
# Processing Record 39 of Set 11 | homa bay
# Processing Record 40 of Set 11 | huarmey
# Processing Record 41 of Set 11 | comodoro rivadavia
# Processing Record 42 of Set 11 | lakatoro
# Processing Record 43 of Set 11 | jiamusi
# Processing Record 44 of Set 11 | vanimo
# Processing Record 45 of Set 11 | sakakah
# Processing Record 46 of Set 11 | zabol
# Processing Record 47 of Set 11 | mabaruma
# Processing Record 48 of Set 11 | roald
# Processing Record 49 of Set 11 | tayginka
# Processing Record 50 of Set 11 | pochutla
# Processing Record 1 of Set 12 | nemuro
# Processing Record 2 of Set 12 | krasnoborsk
# Processing Record 3 of Set 12 | eura
# Processing Record 4 of Set 12 | qui nhon
# Processing Record 5 of Set 12 | rawlins
# Processing Record 6 of Set 12 | marv dasht
# City not found. Skipping...
# Processing Record 7 of Set 12 | ascension
# Processing Record 8 of Set 12 | guarapari
# Processing Record 9 of Set 12 | faya
# Processing Record 10 of Set 12 | kjollefjord
# Processing Record 11 of Set 12 | yulara
# Processing Record 12 of Set 12 | antsohihy
# Processing Record 13 of Set 12 | gallup
# Processing Record 14 of Set 12 | hailar
# Processing Record 15 of Set 12 | sungaipenuh
# Processing Record 16 of Set 12 | sao filipe
# Processing Record 17 of Set 12 | upington
# Processing Record 18 of Set 12 | armidale
# Processing Record 19 of Set 12 | okhotsk
# Processing Record 20 of Set 12 | ocala
# Processing Record 21 of Set 12 | dolgorukovo
# Processing Record 22 of Set 12 | mantua
# Processing Record 23 of Set 12 | bismarck
# Processing Record 24 of Set 12 | leiyang
# Processing Record 25 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 26 of Set 12 | coari
# Processing Record 27 of Set 12 | burica
# City not found. Skipping...
# Processing Record 28 of Set 12 | harper
# Processing Record 29 of Set 12 | hay river
# Processing Record 30 of Set 12 | sekoma
# Processing Record 31 of Set 12 | henzada
# City not found. Skipping...
# Processing Record 32 of Set 12 | puerto madryn
# Processing Record 33 of Set 12 | wenatchee
# Processing Record 34 of Set 12 | kalmunai
# Processing Record 35 of Set 12 | phan thiet
# Processing Record 36 of Set 12 | nemchinovka
# Processing Record 37 of Set 12 | conde
# Processing Record 38 of Set 12 | srednekolymsk
# Processing Record 39 of Set 12 | sindor
# Processing Record 40 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 41 of Set 12 | pontes e lacerda
# Processing Record 42 of Set 12 | mombasa
# Processing Record 43 of Set 12 | basse-pointe
# Processing Record 44 of Set 12 | linqiong
# Processing Record 45 of Set 12 | vredendal
# Processing Record 46 of Set 12 | lethem
# Processing Record 47 of Set 12 | verkhoyansk
# Processing Record 48 of Set 12 | wenling
# Processing Record 49 of Set 12 | turiacu
# Processing Record 50 of Set 12 | coquimbo
# Processing Record 1 of Set 13 | sergach
# Processing Record 2 of Set 13 | bilibino
# Processing Record 3 of Set 13 | khani
# Processing Record 4 of Set 13 | la ronge
# Processing Record 5 of Set 13 | progreso
# Processing Record 6 of Set 13 | grasse
# Processing Record 7 of Set 13 | port keats
# Processing Record 8 of Set 13 | dali
# Processing Record 9 of Set 13 | biltine
# Processing Record 10 of Set 13 | zhaotong
# Processing Record 11 of Set 13 | imbituba
# Processing Record 12 of Set 13 | santa maria
# Processing Record 13 of Set 13 | paamiut
# Processing Record 14 of Set 13 | adwa
# Processing Record 15 of Set 13 | san cristobal
# Processing Record 16 of Set 13 | mandalgovi
# Processing Record 17 of Set 13 | port hardy
# Processing Record 18 of Set 13 | gangotri
# City not found. Skipping...
# Processing Record 19 of Set 13 | shiyan
# Processing Record 20 of Set 13 | houma
# Processing Record 21 of Set 13 | collie
# Processing Record 22 of Set 13 | vestmannaeyjar
# Processing Record 23 of Set 13 | taksimo
# Processing Record 24 of Set 13 | jalingo
# Processing Record 25 of Set 13 | mirnyy
# Processing Record 26 of Set 13 | barranca
# Processing Record 27 of Set 13 | bischwiller
# Processing Record 28 of Set 13 | galesong
# Processing Record 29 of Set 13 | asau
# Processing Record 30 of Set 13 | port blair
# Processing Record 31 of Set 13 | pasighat
# Processing Record 32 of Set 13 | grudziadz
# Processing Record 33 of Set 13 | svetlogorsk
# Processing Record 34 of Set 13 | ambanja
# Processing Record 35 of Set 13 | sergeyevka
# Processing Record 36 of Set 13 | boffa
# Processing Record 37 of Set 13 | road town
# Processing Record 38 of Set 13 | muisne
# Processing Record 39 of Set 13 | yeniseysk
# Processing Record 40 of Set 13 | nedjo
# Processing Record 41 of Set 13 | birin
# Processing Record 42 of Set 13 | atyrau
# Processing Record 43 of Set 13 | manama
# Processing Record 44 of Set 13 | pousat
# City not found. Skipping...
# Processing Record 45 of Set 13 | nizhniy kuranakh
# Processing Record 46 of Set 13 | rock hill
# Processing Record 47 of Set 13 | haian
# Processing Record 48 of Set 13 | cotonou
# Processing Record 49 of Set 13 | santa maria del oro
# Processing Record 50 of Set 13 | juneau
# Processing Record 1 of Set 14 | kruisfontein
# Processing Record 2 of Set 14 | aukra
# Processing Record 3 of Set 14 | tura
# Processing Record 4 of Set 14 | domoni
# Processing Record 5 of Set 14 | vilhena
# Processing Record 6 of Set 14 | christchurch
# Processing Record 7 of Set 14 | sabang
# Processing Record 8 of Set 14 | puerto baquerizo moreno
# Processing Record 9 of Set 14 | mikumi
# Processing Record 10 of Set 14 | general roca
# Processing Record 11 of Set 14 | cascais
# Processing Record 12 of Set 14 | cabedelo
# Processing Record 13 of Set 14 | ixtapa
# Processing Record 14 of Set 14 | kozova
# Processing Record 15 of Set 14 | xuanzhou
# Processing Record 16 of Set 14 | koplik
# Processing Record 17 of Set 14 | sovetskiy
# Processing Record 18 of Set 14 | churapcha
# Processing Record 19 of Set 14 | taian
# Processing Record 20 of Set 14 | ratnapura
# Processing Record 21 of Set 14 | college
# Processing Record 22 of Set 14 | filimonovo
# Processing Record 23 of Set 14 | kushiro
# Processing Record 24 of Set 14 | brzesko
# Processing Record 25 of Set 14 | bangassou
# Processing Record 26 of Set 14 | liverpool
# Processing Record 27 of Set 14 | ust-omchug
# Processing Record 28 of Set 14 | oktyabrskiy
# Processing Record 29 of Set 14 | hermiston
# Processing Record 30 of Set 14 | xique-xique
# Processing Record 31 of Set 14 | northam
# Processing Record 32 of Set 14 | bonavista
# Processing Record 33 of Set 14 | chiredzi
# Processing Record 34 of Set 14 | chokwe
# Processing Record 35 of Set 14 | abha
# Processing Record 36 of Set 14 | felidhoo
# City not found. Skipping...
# Processing Record 37 of Set 14 | vasilyevo
# Processing Record 38 of Set 14 | mount gambier
# Processing Record 39 of Set 14 | higuey
# City not found. Skipping...
# Processing Record 40 of Set 14 | port hedland
# Processing Record 41 of Set 14 | nipawin
# Processing Record 42 of Set 14 | gondar
# Processing Record 43 of Set 14 | alibag
# Processing Record 44 of Set 14 | karatau
# Processing Record 45 of Set 14 | kamsack
# Processing Record 46 of Set 14 | boyabat
# Processing Record 47 of Set 14 | north platte
# Processing Record 48 of Set 14 | newport
# Processing Record 49 of Set 14 | sioux lookout
# Processing Record 50 of Set 14 | sao gotardo
# Processing Record 1 of Set 15 | kuryk
# Processing Record 2 of Set 15 | mackenzie
# Processing Record 3 of Set 15 | tilichiki
# Processing Record 4 of Set 15 | grand-santi
# Processing Record 5 of Set 15 | naze
# Processing Record 6 of Set 15 | oussouye
# Processing Record 7 of Set 15 | abiy adi
# City not found. Skipping...
# Processing Record 8 of Set 15 | te anau
# Processing Record 9 of Set 15 | sambava
# Processing Record 10 of Set 15 | hoa binh
# Processing Record 11 of Set 15 | vannes
# Processing Record 12 of Set 15 | pokrovsk
# Processing Record 13 of Set 15 | rengo
# Processing Record 14 of Set 15 | weinan
# Processing Record 15 of Set 15 | itacarambi
# Processing Record 16 of Set 15 | phalodi
# Processing Record 17 of Set 15 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 18 of Set 15 | villa carlos paz
# Processing Record 19 of Set 15 | sandakan
# Processing Record 20 of Set 15 | banda aceh
# Processing Record 21 of Set 15 | maniwaki
# Processing Record 22 of Set 15 | saint-francois
# Processing Record 23 of Set 15 | opuwo
# Processing Record 24 of Set 15 | benoy
# Processing Record 25 of Set 15 | seoni
# Processing Record 26 of Set 15 | peabiru
# Processing Record 27 of Set 15 | fulton
# Processing Record 28 of Set 15 | kijang
# Processing Record 29 of Set 15 | pandan
# Processing Record 30 of Set 15 | tyssedal
# Processing Record 31 of Set 15 | thaton
# Processing Record 32 of Set 15 | baoding
# Processing Record 33 of Set 15 | beloha
# Processing Record 34 of Set 15 | alihe
# Processing Record 35 of Set 15 | atar
# Processing Record 36 of Set 15 | selma
# Processing Record 37 of Set 15 | vila velha
# Processing Record 38 of Set 15 | lazi
# Processing Record 39 of Set 15 | worland
# Processing Record 40 of Set 15 | kedrovyy
# Processing Record 41 of Set 15 | tarata
# Processing Record 42 of Set 15 | riyadh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     East London -33.0153   27.9116     66.88        87         100
# 1  Severo-Kurilsk  50.6789  156.1250     28.83        75          91
# 2         Warmbad -28.4500   18.7333     60.84        63           0
# 3       Mogadishu   2.0371   45.3438     78.73        85         100
# 4      Chokurdakh  70.6333  147.9167    -23.78        99         100
# 5     Yellowknife  62.4560 -114.3525    -21.48        76          75
# 6         Ushuaia -54.8000  -68.3000     58.62        51          20
# 7           Bluff -46.6000  168.3333     59.81        64          15
# 8       Busselton -33.6500  115.3333     74.93        47          98
# 9        Cherskiy  68.7500  161.3000    -26.59        99         100
#
#    Wind Speed Country Current Description
# 0        6.58      ZA          light rain
# 1       26.98      RU     overcast clouds
# 2        9.31      NA           clear sky
# 3       16.91      SO     overcast clouds
# 4        5.97      RU     overcast clouds
# 5        3.44      CA          light snow
# 6       17.27      AR          few clouds
# 7       23.73      NZ          few clouds
# 8        6.62      AU     overcast clouds
# 9        4.23      RU     overcast clouds

# %%
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     East London      ZA -33.0153   27.9116     66.88        87         100
# 1  Severo-Kurilsk      RU  50.6789  156.1250     28.83        75          91
# 2         Warmbad      NA -28.4500   18.7333     60.84        63           0
# 3       Mogadishu      SO   2.0371   45.3438     78.73        85         100
# 4      Chokurdakh      RU  70.6333  147.9167    -23.78        99         100
# 5     Yellowknife      CA  62.4560 -114.3525    -21.48        76          75
# 6         Ushuaia      AR -54.8000  -68.3000     58.62        51          20
# 7           Bluff      NZ -46.6000  168.3333     59.81        64          15
# 8       Busselton      AU -33.6500  115.3333     74.93        47          98
# 9        Cherskiy      RU  68.7500  161.3000    -26.59        99         100
#
#    Wind Speed Current Description
# 0        6.58          light rain
# 1       26.98     overcast clouds
# 2        9.31           clear sky
# 3       16.91     overcast clouds
# 4        5.97     overcast clouds
# 5        3.44          light snow
# 6       17.27          few clouds
# 7       23.73          few clouds
# 8        6.62     overcast clouds
# 9        4.23     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
